# %% [markdown]
# # Python Fundamentals I: variables, lists and dictionaries
#
# Aasdf

# %% [markdown]
# ## Python as a simple calculator

# %%
10 + (2+4)**2 -3*(5-3)
# Out:
# 40

# %% [markdown]
# ## Python as a scientific programmable calculator

# %%
x = 4
3*x + 2*x
# Out:
# 20

# %% [markdown]
# ## Python build-in objects
#
# ### Numbers

# %%
x=4
type(x)
# Out:
# int

# %%
y = 23.456456
type(y)
print("Ciao  {0:.3f}".format(y))
print(f"Ciao  {y:.3f}")
# Out:
# Ciao  23.456
# Ciao  23.456

# %% [markdown]
# ### Strings

# %%
z = "Ciao!"
type(z)
# Out:
# str

# %% [markdown]
# ### Lists

# %%
asedf = [12, "Hello", 1.33, 2.53]
asedf[2]
# Out:
# 1.33

# %%
asedf[-1]
# Out:
# 2.53

# %% [markdown]
# ### Dictionaries

# %%
student = {"name": "Marco", "surname": "Rossi", "age": 27}

# %%
student["name"]
# Out:
# 'Marco'

# %%
student["age"] = 23
student
# Out:
# {'name': 'Marco', 'surname': 'Rossi', 'age': 23}

# %% [markdown]
# ## Import modules

# %%
import math
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %% [markdown]
# ## Getting help!

# %% [markdown]
# ## Repetitive tasks: the `for` loop
#
# - indentazione!

# %%
students = ["A", "B", "C"]
for stud in students:
    print(stud)
# Out:
# A
# B
# C

# %%
for i in range(5):
    print("Iteration number", i)
# Out:
# Iteration number 0
# Iteration number 1
# Iteration number 2
# Iteration number 3
# Iteration number 4

# %% [markdown]
# ## Conditional statemens: `if` and `else`

# %%
x=4
